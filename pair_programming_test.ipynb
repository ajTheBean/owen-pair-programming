# %%
import pair_programming as pp

# %%
print(pp.polar_to_cartesian(0,0))

print(pp.polar_to_cartesian(-34.2384932,230948.23432))
# Out:
# (np.float64(0.0), np.float64(0.0))
# (np.float64(32.35117519126716), np.float64(11.210525427043404))
